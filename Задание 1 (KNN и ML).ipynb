# %%
import numpy as np  
import matplotlib.pyplot as plt  
from sklearn.datasets import make_circles, make_moons  
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

x1, y1 = make_circles(n_samples=100, factor=0.5, noise=0.1, shuffle=True, random_state=42)
plt.scatter(x1[:, 0], x1[:, 1], c=y1, cmap='viridis')
plt.show()
x1_train, x1_test, y1_train, y1_test = train_test_split(x1, y1, test_size=0.2, train_size=0.8, random_state = 0)
k_values = range(1, 9)
accuracy_scores = []
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x1_train, y1_train)
    y1_pred = knn.predict(x1_test)
    accuracy = accuracy_score(y1_test, y1_pred)
    accuracy_scores.append(accuracy)
plt.plot(k_values, accuracy_scores)
plt.xlabel('k')
plt.ylabel('accuracy')
plt.show()
accuracy = accuracy_score(y1_test, y1_pred)
precision = precision_score(y1_test, y1_pred)
recall = recall_score(y1_test, y1_pred)
f1 = f1_score(y1_test, y1_pred)
print(f'accuracy: {accuracy}\n precision: {precision}\n recall: {recall}\n f1: {F1}')
matrix = confusion_matrix(y1_test, y1_pred)
print(matrix)

x2 = np.random.uniform(-10, 10, 200)
y2 = np.random.uniform(-10, 10, 200)
class1 = (x2 < 0) & (y2 < 0) | (x2 > 0) & (y2 > 0)
class2 = (x2 < 0) & (y2 > 0) | (x2 > 0) & (y2 < 0)
dataset = np.array([x2, y2, class1, class2]).T
plt.scatter(x2, y2, c=class1, s=50, alpha=0.5)
plt.scatter(x2, y2, c=class2, s=50, alpha=0.5)
plt.show()
train_set, test_set = train_test_split(dataset, test_size=0.2, train_size=0.8, random_state = 0)
k_values = range(1, 9)
accuracy_scores = []
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(train_set[:, :2], train_set[:, 2])
    y2_pred = knn.predict(test_set[:, :2])
    accuracy = accuracy_score(test_set[:, 2], y2_pred)
    accuracy_scores.append(accuracy)
plt.plot(k_values, accuracy_scores)
plt.xlabel('k')
plt.ylabel('accuracy')
plt.show()
accuracy = accuracy_score(test_set[:, 2], y2_pred)
precision = precision_score(test_set[:, 2], y2_pred)
recall = recall_score(test_set[:, 2], y2_pred)
f1 = f1_score(test_set[:, 2], y2_pred)
print(f'accuracy: {accuracy}\n precision: {precision}\n recall: {recall}\n f1: {F1}')
matrix = confusion_matrix(test_set[:, 2], y2_pred)
print(matrix)

x3, y3 = make_moons(n_samples=100, noise=0.01, random_state=0)
plt.scatter(x3[:, 0], x3[:, 1], c=y3)
plt.show()
x3_train, x3_test, y3_train, y3_test = train_test_split(x3, y3, test_size=0.2, train_size=0.8, random_state = 0)
k_values = range(1, 9)
accuracy_scores = []
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x3_train, y3_train)
    y3_pred = knn.predict(x3_test)
    accuracy = accuracy_score(y3_test, y3_pred)
    accuracy_scores.append(accuracy)
plt.plot(k_values, accuracy_scores)
plt.xlabel('k')
plt.ylabel('accuracy')
plt.show()
accuracy = accuracy_score(y3_test, y3_pred)
precision = precision_score(y3_test, y3_pred)
recall = recall_score(y3_test, y3_pred)
f1 = f1_score(y3_test, y3_pred)
print(f'accuracy: {accuracy}\n precision: {precision}\n recall: {recall}\n f1: {F1}')
matrix = confusion_matrix(y3_test, y3_pred)
print(matrix)
# Out:
# accuracy: 0.95
#  precision: 1.0
#  recall: 0.9
#  f1: 0.9302325581395349
# [[10  0]
#  [ 1  9]]
# accuracy: 1.0
#  precision: 1.0
#  recall: 1.0
#  f1: 0.9302325581395349
# [[20  0]
#  [ 0 20]]
# accuracy: 1.0
#  precision: 1.0
#  recall: 1.0
#  f1: 0.9302325581395349
# [[ 9  0]
#  [ 0 11]]
